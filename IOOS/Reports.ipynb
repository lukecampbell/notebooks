# %%
from reports.github import *
from dateutil.parser import parse as dateparse

# %%
start = dateparse('2015-03-01')
end = dateparse('2015-04-01')

# %%
count_issues_created('ioos/compliance-checker', start, end)
# Out:
# /Users/lcampbell/.virtualenvs/work/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# ...

# %%
count_comments_created('ioos/compliance-checker', start, end)
# Out:
# 2015-04-01 10:01:03,272 - reports.github - INFO - https://api.github.com/repos/ioos/compliance-checker/issues/comments?since=2015-03-01T00:00:00+00:00
# INFO:reports.github:https://api.github.com/repos/ioos/compliance-checker/issues/comments?since=2015-03-01T00:00:00+00:00
# /Users/lcampbell/.virtualenvs/work/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# ...

# %%
url = 'https://api.github.com/repos/ioos/compliance-checker/issues/comments?since=2015-03-01T00:00:00+00:00'
import requests
from requests.auth import HTTPBasicAuth
from reports.config import ACCESS_TOKEN
from reports.github import parse_links
r = requests.get(url, auth=HTTPBasicAuth(ACCESS_TOKEN,''))
# Out:
# /Users/lcampbell/.virtualenvs/work/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning

# %%
links = parse_links(r)

# %%
r = requests.get(links['next'], auth=HTTPBasicAuth(ACCESS_TOKEN,''))
# Out:
# /Users/lcampbell/.virtualenvs/work/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning

# %%
# Out:
# [{u'body': u'https://github.com/ocefpaf/cf_units is my working fork of the **official** https://github.com/SciTools/cf_units.\r\n\r\nThe transition should be smooth (brave last words).  I think I got almost of all of `udunitspy` functionality, used in compliance-checker, in the example [here](http://nbviewer.ipython.org/gist/ocefpaf/60ecac928612f5ae8fed).  However, I recommend waiting a little bit for a release.  Here is our roadmap for the next days: https://github.com/SciTools/cf_units/issues/15#issuecomment-82898719',
#   u'created_at': u'2015-03-20T19:00:20Z',
#   u'html_url': u'https://github.com/ioos/compliance-checker/issues/62#issuecomment-84100875',
#   u'id': 84100875,
#   u'issue_url': u'https://api.github.com/repos/ioos/compliance-checker/issues/62',
#   u'updated_at': u'2015-03-20T19:00:20Z',
#   u'url': u'https://api.github.com/repos/ioos/compliance-checker/issues/comments/84100875',
#   u'user': {u'avatar_url': u'https://avatars.githubusercontent.com/u/950575?v=3',
# ...
